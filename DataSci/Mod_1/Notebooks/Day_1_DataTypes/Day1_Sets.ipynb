# %% [markdown]
# ## **SETS**

# %%
emptyset=set()
type(emptyset)
# Out:
# set

# %%
# Create a non-empty set within curly braces
non_empty_set = {1,6,4,'abc'}

# %%
# Mutability in set
non_empty_set = non_empty_set | {1,7}
print(non_empty_set)
# Out:
# {1, 4, 6, 7, 'abc'}
