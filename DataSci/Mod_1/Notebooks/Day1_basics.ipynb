# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# Order of operations:
#PEMDAS
# Parentheses   
# Exponents
# Multiplication and Division (from left to right)
# Addition and Subtraction (from left to right)
result = 2 + 10 * 10 + 3
print("Result of the expression is:", result)
# Out:
# Result of the expression is: 105

# %%
x = 2
func_evaluated_at_2 = (x**2)+(3*x)-4
print("Function evaluated at x=2 is:", func_evaluated_at_2==0)
x=-1
func_evaluated_at_minus1 = (x**2)+(3*x)-4
print("Function evaluated at x=-1 is:", func_evaluated_at_minus1==0)   
x=1
func_evaluated_at_1 = (x**2)+(3*x)-4
print("Function evaluated at x=1 is:", func_evaluated_at_1==0)
func_evaluated_at_1 >= func_evaluated_at_minus1
# Out:
# Function evaluated at x=2 is: False
# Function evaluated at x=-1 is: False
# Function evaluated at x=1 is: True
# True

# %%
print('''
Alok :Hi I am Alok.I will be your instructor for the first module
Anfal: Thank you
''')
my="text"
type(my)
# Out:
# Alok :Hi I am Alok.I will be your instructor for the first module
# Anfal: Thank you
# str

# %% [markdown]
# ## **SOME BASIC OPERATIONS IN PYTHON**

# %%
machine_learning='Neural Networks '

len(machine_learning)

print(machine_learning)
# Out:
# Neural Networks

# %%
machine_learning.count("N ")
# Out:
# 0

# %%
print("a"*2)
# Out:
# aa
