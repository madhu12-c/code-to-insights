# %% [markdown]
# ## **INTRO OF LIST**

# %%
mylist= [1,2,3,4,5]
print(mylist)
# Out:
# [1, 2, 3, 4, 5]

# %%
mylist
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## **Mutablity**

# %%
# create a list
my_list = [1, 2, 3, 4, 5]

# modify the list
my_list[0] = 10

# print out the modified list
print(my_list)
# Out:
# [10, 2, 3, 4, 5]

# %%
loss_function=[1,2,3,4,5]
print (loss_function)
len(loss_function)
sum(loss_function)
result= sum(loss_function)/len(loss_function)
print(result)
# Out:
# [1, 2, 3, 4, 5]
# 3.0
